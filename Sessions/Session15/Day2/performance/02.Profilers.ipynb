# %% [markdown]
# ## Profilers for Python
#
# In this session we will cover two kinds of profiling: deterministic and statistical profiling.
#
# We'll use both simpler approaches to profile software and more involved softwares.

# %% [markdown]
# ### Built-in Jupyter methods

# %%
def foo():
    aux = 0
    for i in range(10000):
        aux = i * i

# %%
# %timeit foo()
# Out:
# 239 µs ± 1.13 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %prun foo()

# %% [markdown]
# ### Tracing
#
# You can set a trace function that's triggered every time the VM enters or exits both Python and C functions.
#
# The python interpreter converts programs to bytecodes before beginning execution. Execution itself consist of looping over these bytecodes and performing specific operations over each one.

# %%
# ⚠️ Run this code on your Python CLI

def fib(n):
    i, f1, f2 = 1, 1, 1
    while i < n:
        f1, f2 = f2, f1 + f2
        i += 1
    return f1

import opcode


def show_trace(frame, event, arg):
    frame.f_trace_opcodes = True
    code = frame.f_code
    offset = frame.f_lasti

    print(f"| {event:10} | {str(arg):>4} |", end=' ')
    print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=' ')
    print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")
    return show_trace

import sys

header = f"| {'event':10} | {'arg':>4} | line | offset | {'opcode':^18} | {'locals':^35} |"
print(header)
sys.settrace(show_trace)
fib(3)
sys.settrace(None)
# Out:
# | event      |  arg | line | offset |       opcode       |               locals                |
# | call       | None |  675 |     -1 | <0>                | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | line       | None |  683 |      0 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  683 |      0 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  683 |      2 | LOAD_CONST         | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  683 |      4 | IS_OP              | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  683 |      6 | POP_JUMP_IF_FALSE  | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | line       | None |  686 |     12 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  686 |     12 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  686 |     14 | LOAD_METHOD        | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  686 |     16 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  686 |     18 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  686 |     20 | CALL_METHOD        | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | call       | None |  643 |     -1 | <0>                | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | line       | None |  644 |      0 | SETUP_FINALLY      | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  644 |      0 | SETUP_FINALLY      | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | line       | None |  645 |      2 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |      2 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |      4 | LOAD_ATTR          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |      6 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |      8 | LOAD_ATTR          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |     10 | BINARY_SUBSCR      | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |     12 | STORE_FAST         | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | opcode     | None |  645 |     14 | POP_BLOCK          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | opcode     | None |  645 |     16 | JUMP_FORWARD       | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | line       | None |  673 |    184 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | opcode     | None |  673 |    184 | LOAD_FAST          | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | opcode     | None |  673 |    186 | RETURN_VALUE       | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | return     | True |  673 |    186 | RETURN_VALUE       | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>, 'value': True} |
# | opcode     | None |  686 |     22 | RETURN_VALUE       | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | return     | True |  686 |     22 | RETURN_VALUE       | {'self': <traitlets.traitlets.Bool object at 0x10695f6a0>, 'obj': <ipykernel.zmqshell.ZMQInteractiveShell object at 0x107ef0ca0>, 'cls': <class 'ipykernel.zmqshell.ZMQInteractiveShell'>} |
# | call       | None |  261 |     -1 | <0>                | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | line       | None |  263 |      0 | LOAD_GLOBAL        | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | opcode     | None |  263 |      0 | LOAD_GLOBAL        | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | opcode     | None |  263 |      2 | LOAD_DEREF         | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | opcode     | None |  263 |      4 | LOAD_FAST          | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | opcode     | None |  263 |      6 | LOAD_FAST          | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | opcode     | None |  263 |      8 | CALL_FUNCTION      | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | call       | None |   86 |     -1 | <0>                | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | line       | None |   87 |      0 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |      0 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |      2 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |      4 | BUILD_MAP          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |      6 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |      8 | DICT_MERGE         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |     10 | CALL_FUNCTION_EX   | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |     12 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   87 |     14 | STORE_ATTR         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | line       | None |   88 |     16 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     16 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     18 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     20 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     22 | ROT_THREE          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     24 | ROT_TWO            | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     26 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     28 | STORE_ATTR         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     30 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     32 | STORE_ATTR         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     34 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   88 |     36 | STORE_ATTR         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | line       | None |   90 |     38 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     38 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     40 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     42 | LOAD_CONST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     44 | LOAD_CONST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     46 | CALL_FUNCTION      | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | opcode     | None |   90 |     48 | STORE_FAST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}} |
# | line       | None |   91 |     50 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   91 |     50 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   91 |     52 | LOAD_CONST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   91 |     54 | IS_OP              | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   91 |     56 | POP_JUMP_IF_FALSE  | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | line       | None |   92 |     58 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   92 |     58 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   92 |     60 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   92 |     62 | CALL_FUNCTION      | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   92 |     64 | LOAD_ATTR          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | opcode     | None |   92 |     66 | STORE_FAST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': None} |
# | line       | None |   93 |     68 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |   93 |     68 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |   93 |     70 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |   93 |     72 | STORE_ATTR         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |   93 |     74 | LOAD_CONST         | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |   93 |     76 | RETURN_VALUE       | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | return     | None |   93 |     76 | RETURN_VALUE       | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>, 'func': <function CachingCompiler.extra_flags at 0x106774670>, 'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'doc': 'Helper for @contextmanager decorator.'} |
# | opcode     | None |  263 |     10 | RETURN_VALUE       | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | return     | <contextlib._GeneratorContextManager object at 0x110cb7e20> |  263 |     10 | RETURN_VALUE       | {'args': (<ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 8192), 'kwds': {}, 'func': <function CachingCompiler.extra_flags at 0x106774670>} |
# | call       | None |  114 |     -1 | <0>                | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | line       | None |  117 |      0 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |      0 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |      2 | DELETE_ATTR        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |      4 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |      6 | DELETE_ATTR        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |      8 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  117 |     10 | DELETE_ATTR        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | line       | None |  118 |     12 | SETUP_FINALLY      | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  118 |     12 | SETUP_FINALLY      | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | line       | None |  119 |     14 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  119 |     14 | LOAD_GLOBAL        | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  119 |     16 | LOAD_FAST          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  119 |     18 | LOAD_ATTR          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  119 |     20 | CALL_FUNCTION      | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | call       | None |  174 |     -1 | <0>                | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | line       | None |  177 |      0 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |      0 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |      2 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |      4 | UNARY_INVERT       | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |      6 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |      8 | BINARY_AND         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | opcode     | None |  177 |     10 | STORE_FAST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192} |
# | line       | None |  180 |     12 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     12 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     14 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     16 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     18 | BINARY_OR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     20 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  180 |     22 | STORE_ATTR         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | line       | None |  181 |     24 | SETUP_FINALLY      | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  181 |     24 | SETUP_FINALLY      | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | line       | None |  182 |     26 | LOAD_CONST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  182 |     26 | LOAD_CONST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  182 |     28 | YIELD_VALUE        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | return     | None |  182 |     28 | YIELD_VALUE        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'flags': 8192, 'turn_on_bits': 8192} |
# | opcode     | None |  119 |     22 | POP_BLOCK          | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | opcode     | None |  119 |     24 | RETURN_VALUE       | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | return     | None |  119 |     24 | RETURN_VALUE       | {'self': <contextlib._GeneratorContextManager object at 0x110cb7e20>} |
# | call       | None |  142 |     -1 | <0>                | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | line       | None |  143 |      0 | LOAD_GLOBAL        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |      0 | LOAD_GLOBAL        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |      2 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |      4 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |      6 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |      8 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |     10 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |     12 | LOAD_CONST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |     14 | CALL_FUNCTION      | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | opcode     | None |  143 |     16 | STORE_FAST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec'} |
# | line       | None |  144 |     18 | LOAD_GLOBAL        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>} |
# | opcode     | None |  144 |     18 | LOAD_GLOBAL        | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>} |
# | opcode     | None |  144 |     20 | GET_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>} |
# | opcode     | None |  144 |     22 | FOR_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>} |
# | opcode     | None |  144 |     24 | STORE_FAST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>} |
# | line       | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     28 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     30 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     32 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     34 | BINARY_AND         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  145 |     36 | POP_JUMP_IF_FALSE  | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | line       | None |  144 |     22 | FOR_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  144 |     22 | FOR_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | opcode     | None |  144 |     24 | STORE_FAST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 1, 0, 'beta', 1), (2, 2, 0, 'alpha', 0), 16)} |
# | line       | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     28 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     30 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     32 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     34 | BINARY_AND         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  145 |     36 | POP_JUMP_IF_FALSE  | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | line       | None |  144 |     22 | FOR_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  144 |     22 | FOR_ITER           | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | opcode     | None |  144 |     24 | STORE_FAST         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 1), (2, 3, 0, 'final', 0), 0)} |
# | line       | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# | opcode     | None |  145 |     26 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# | opcode     | None |  145 |     28 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# | opcode     | None |  145 |     30 | LOAD_FAST          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# | opcode     | None |  145 |     32 | LOAD_ATTR          | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# | opcode     | None |  145 |     34 | BINARY_AND         | {'self': <ipykernel.compiler.XCachingCompiler object at 0x107ef0d30>, 'source': <ast.Module object at 0x110cb77c0>, 'filename': '/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py', 'symbol': 'exec', 'codeob': <code object <module> at 0x107f7d450, file "/var/folders/4k/z68m9p5522jf8zn3xvx449ww0000gn/T/ipykernel_53829/4067019739.py", line 28>, 'feature': _Feature((2, 2, 0, 'alpha', 2), (3, 0, 0, 'alpha', 0), 131072)} |
# ...
# | opcode     | None |   29 |      2 | LOAD_METHOD        | {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n# cProfile.run(statement, filename=None, sort=-1)', 'import numpy as np\n\ncProfile.run("2**200000")', "def add_emoji():\n    arr=[]\n    arr.append('🔥')\n\ndef multiply():\n    arr=[]\n    for i in range(0,400000):\n        arr.append(i * 2)\n        add_emoji()\n\ndef main():\n    multiply()\n    print('end')\n\nif __name__ == '__main__':\n    profiler = cProfile.run('main()')", "import  pstats\n# p = pstats.Stats('profile.dat', stream = s)\nstats = pstats.Stats(profiler)\nstats.dump_stats('data.txt')", "# installing the module\nget_ipython().system('pip install snakeviz')", 'import glob', '# load it on the notebook\nget_ipython().run_line_magic(\'snakeviz\', "glob.glob(\'*.txt\')")', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\ndef fib(n):\n    i, f1, f2 = 1, 1, 1\n    while i < n:\n        f1, f2 = f2, f1 + f2\n        i += 1\n    return f1\n\nimport opcode\n\n\ndef show_trace(frame, event, arg):\n    frame.f_trace_opcodes = True\n    code = frame.f_code\n    offset = frame.f_lasti\n\n    print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n    print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n    print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n    return show_trace\n\nimport sys\n\nheader = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\nprint(header)\nsys.settrace(show_trace)\nfib(3)\nsys.settrace(None)'], '_oh': {}, '_dh': [PosixPath('/Users/meh/Desktop/school/lsstc_dsfp/LSSTC-DSFP-Sessions/Sessions/Session15/Day2/performance')], 'In': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n ...
# | opcode     | None |   29 |      4 | LOAD_CONST         | {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n# cProfile.run(statement, filename=None, sort=-1)', 'import numpy as np\n\ncProfile.run("2**200000")', "def add_emoji():\n    arr=[]\n    arr.append('🔥')\n\ndef multiply():\n    arr=[]\n    for i in range(0,400000):\n        arr.append(i * 2)\n        add_emoji()\n\ndef main():\n    multiply()\n    print('end')\n\nif __name__ == '__main__':\n    profiler = cProfile.run('main()')", "import  pstats\n# p = pstats.Stats('profile.dat', stream = s)\nstats = pstats.Stats(profiler)\nstats.dump_stats('data.txt')", "# installing the module\nget_ipython().system('pip install snakeviz')", 'import glob', '# load it on the notebook\nget_ipython().run_line_magic(\'snakeviz\', "glob.glob(\'*.txt\')")', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\ndef fib(n):\n    i, f1, f2 = 1, 1, 1\n    while i < n:\n        f1, f2 = f2, f1 + f2\n        i += 1\n    return f1\n\nimport opcode\n\n\ndef show_trace(frame, event, arg):\n    frame.f_trace_opcodes = True\n    code = frame.f_code\n    offset = frame.f_lasti\n\n    print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n    print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n    print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n    return show_trace\n\nimport sys\n\nheader = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\nprint(header)\nsys.settrace(show_trace)\nfib(3)\nsys.settrace(None)'], '_oh': {}, '_dh': [PosixPath('/Users/meh/Desktop/school/lsstc_dsfp/LSSTC-DSFP-Sessions/Sessions/Session15/Day2/performance')], 'In': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n ...
# | opcode     | None |   29 |      6 | CALL_METHOD        | {'__name__': '__main__', '__doc__': 'Automatically created module for IPython interactive environment', '__package__': None, '__loader__': None, '__spec__': None, '__builtin__': <module 'builtins' (built-in)>, '__builtins__': <module 'builtins' (built-in)>, '_ih': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n# cProfile.run(statement, filename=None, sort=-1)', 'import numpy as np\n\ncProfile.run("2**200000")', "def add_emoji():\n    arr=[]\n    arr.append('🔥')\n\ndef multiply():\n    arr=[]\n    for i in range(0,400000):\n        arr.append(i * 2)\n        add_emoji()\n\ndef main():\n    multiply()\n    print('end')\n\nif __name__ == '__main__':\n    profiler = cProfile.run('main()')", "import  pstats\n# p = pstats.Stats('profile.dat', stream = s)\nstats = pstats.Stats(profiler)\nstats.dump_stats('data.txt')", "# installing the module\nget_ipython().system('pip install snakeviz')", 'import glob', '# load it on the notebook\nget_ipython().run_line_magic(\'snakeviz\', "glob.glob(\'*.txt\')")', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\ndef fib(n):\n    i, f1, f2 = 1, 1, 1\n    while i < n:\n        f1, f2 = f2, f1 + f2\n        i += 1\n    return f1\n\nimport opcode\n\n\ndef show_trace(frame, event, arg):\n    frame.f_trace_opcodes = True\n    code = frame.f_code\n    offset = frame.f_lasti\n\n    print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n    print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n    print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n    return show_trace\n\nimport sys\n\nheader = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\nprint(header)\nsys.settrace(show_trace)\nfib(3)\nsys.settrace(None)'], '_oh': {}, '_dh': [PosixPath('/Users/meh/Desktop/school/lsstc_dsfp/LSSTC-DSFP-Sessions/Sessions/Session15/Day2/performance')], 'In': ['', 'def foo():\n    aux = 0\n    for i in range(10000):\n        aux = i * i', "get_ipython().run_line_magic('timeit', 'foo()')", "get_ipython().run_line_magic('prun', 'foo()')", '# ⚠️ Run this code on your Python CLI\n\n# def fib(n):\n#     i, f1, f2 = 1, 1, 1\n#     while i < n:\n#         f1, f2 = f2, f1 + f2\n#         i += 1\n#     return f1\n\n# import opcode\n\n\n# def show_trace(frame, event, arg):\n#     frame.f_trace_opcodes = True\n#     code = frame.f_code\n#     offset = frame.f_lasti\n\n#     print(f"| {event:10} | {str(arg):>4} |", end=\' \')\n#     print(f"{frame.f_lineno:>4} | {frame.f_lasti:>6} |", end=\' \')\n#     print(f"{opcode.opname[code.co_code[offset]]:<18} | {str(frame.f_locals):<35} |")\n#     return show_trace\n\n# import sys\n\n# header = f"| {\'event\':10} | {\'arg\':>4} | line | offset | {\'opcode\':^18} | {\'locals\':^35} |"\n# print(header)\n# sys.settrace(show_trace)\n# fib(3)\n# sys.settrace(None)', 'import cProfile\n\n ...

# %% [markdown]
# ### Deterministic profiling
#
# #### cProfile
#
# - Offers you both the total running time of cProfile.run(statement, filename=None, sort=-1)a software as well as specific function calls and times
# - Nice integration with GUI tools and pstats

# %%
import cProfile

# cProfile.run(statement, filename=None, sort=-1)

# %% [markdown]
# You can pass python code or a function name that you want to profile as a string to the statement argument.

# %%
import numpy as np

cProfile.run("2**200000")
# Out:
#          3 function calls in 0.001 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.001    0.001    0.001    0.001 <string>:1(<module>)
#         1    0.000    0.000    0.001    0.001 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# - ncalls : Shows the number of calls made
# - tottime: Total time taken by the given function. Note that the time made in calls to sub-functions are excluded.
# - percall: Total time / No of calls. ( remainder is left out )
# - cumtime: Unlike tottime, this includes time spent in this and all subfunctions that the higher-level function calls. It is most useful and is accurate for recursive functions.
# - The percall following cumtime is calculated as the quotient of cumtime divided by primitive calls. The primitive calls include all the calls that were not included through recursion.

# %%
def add_emoji():
    arr=[]
    arr.append('🔥')

def multiply():
    arr=[]
    for i in range(0,400000):
        arr.append(i * 2)
        add_emoji()

def main():
    multiply()
    print('end')

if __name__ == '__main__':
    profiler = cProfile.run('main()')
# Out:
# end
#          1200030 function calls in 0.111 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400000    0.033    0.000    0.044    0.000 4005984123.py:1(add_emoji)
#         1    0.002    0.002    0.111    0.111 4005984123.py:11(main)
#         1    0.055    0.055    0.109    0.109 4005984123.py:5(multiply)
#         1    0.000    0.000    0.111    0.111 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 iostream.py:202(schedule)
#         2    0.000    0.000    0.000    0.000 iostream.py:429(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:448(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:518(write)
#         1    0.000    0.000    0.000    0.000 iostream.py:90(_event_pipe)
#         1    0.000    0.000    0.000    0.000 socket.py:543(send)
#         1    0.000    0.000    0.000    0.000 threading.py:1066(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1133(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:536(is_set)
#         1    0.000    0.000    0.111    0.111 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    800000    0.022    0.000    0.022    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %% [markdown]
# You can save the data using the following:

# %%
import  pstats
# p = pstats.Stats('profile.dat', stream = s)
stats = pstats.Stats(profiler)
stats.dump_stats('data.txt')

# %% [markdown]
# And use a GUI to visualize it called snakeviz:

# %%
# installing the module
# !pip install snakeviz
# Out:
# Requirement already satisfied: snakeviz in /Users/meh/miniforge3/envs/dsfp/lib/python3.9/site-packages (2.1.1)
# Requirement already satisfied: tornado>=2.0 in /Users/meh/miniforge3/envs/dsfp/lib/python3.9/site-packages (from snakeviz) (6.2)

# %% [markdown]
# %load_ext snakeviz

# %%
import glob

# %%
# load it on the notebook
# %snakeviz glob.glob('*.txt')
# Out:
# UsageError: Line magic function `%snakeviz` not found.

# %%
# opens snakeviz
# %snakeviz main()
# Out:
# UsageError: Line magic function `%snakeviz` not found.

# %% [markdown]
# cProfile has a lot more to offer and I recommend checking the [Python docs](https://docs.python.org/3/library/profile.html#module-cProfile) to learn more about its specific functions.

# %% [markdown]
# ### Statistical profiling
#
# Samples the program counter at regular intervals. The numbers will be statistical approximations instead of exact numbers because of the several process in place.
#
# - Less data to analyze
# - Smaller profiling footprint

# %% [markdown]
# #### pprofile
#
# pprofile offers both deterministic and statistical modes for profiling. We're going to take a look in the statistical mode:
#
# In your CLI, after installing `pprofile` run it in the statistical mode:
#
# ```
# pprofile --statistic 0.01 --exclude-syspath test.py
# ```

# %%
# ⚠️ Run this code on your Python CLI

# import threading
# import time


# def func():
#     time.sleep(1)

# def func2():
#     pass

# t1 = threading.Thread(target=func)
# t2 = threading.Thread(target=func)
# t1.start()
# t2.start()
# (func(), func2())
# t1.join()
# t2.join()

# %% [markdown]
# Hit: indicates the number of calls to each function during the run
