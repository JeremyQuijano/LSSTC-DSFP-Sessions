# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
data_df = pd.read_csv('AIR_GHG_28022023214516359.csv')
data_df
# Out:
#        COU    Country  POL         Pollutant           VAR  \
# 0      AUS  Australia  GHG  Greenhouse gases         TOTAL
# 1      AUS  Australia  GHG  Greenhouse gases         TOTAL
# 2      AUS  Australia  GHG  Greenhouse gases         TOTAL
# 3      AUS  Australia  GHG  Greenhouse gases         TOTAL
# 4      AUS  Australia  GHG  Greenhouse gases         TOTAL
# ...    ...        ...  ...               ...           ...
# 75701  PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75702  PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75703  PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75704  PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
# 75705  PER       Peru  GHG  Greenhouse gases  GHG_GDP_LULU
#
#                                      Variable   YEA  Year   Unit Code  \
# 0           Total  emissions excluding LULUCF  1990  1990  T_CO2_EQVT
# 1           Total  emissions excluding LULUCF  1991  1991  T_CO2_EQVT
# ...

# %%
data_grouped = data_df.groupby(['Country'])['Value'].sum()
print(data_grouped)
# data_grouped['Year']
np.sort(data_grouped, axis=-1)
# Out:
# Country
# Argentina         3.218832e+07
# Australia         7.753663e+07
# Austria           1.271660e+07
# Belarus           1.161572e+07
# Belgium           1.999701e+07
#                       ...
# Switzerland       1.206973e+08
# Türkiye           4.794392e+07
# Ukraine           7.335540e+07
# United Kingdom    9.640411e+07
# United States     9.835585e+08
# Name: Value, Length: 63, dtype: float64
# array([5.87705770e+04, 8.74605748e+05, 1.26415536e+06, 1.42781522e+06,
#        1.94521826e+06, 1.99137297e+06, 2.54152001e+06, 3.00423380e+06,
#        3.04590519e+06, 3.39720997e+06, 3.42896830e+06, 3.86538576e+06,
#        4.25864758e+06, 6.86493677e+06, 7.32183887e+06, 7.32382157e+06,
#        7.46122263e+06, 8.74789942e+06, 8.92270472e+06, 1.00529954e+07,
#        1.02972493e+07, 1.16157218e+07, 1.27166031e+07, 1.56267729e+07,
#        1.65569930e+07, 1.99970105e+07, 2.13899513e+07, 2.34446524e+07,
#        3.14536594e+07, 3.21883179e+07, 3.28786028e+07, 3.46972118e+07,
# ...

# %%
# %%time
groups = data_df.groupby('Country')
plt.figure(figsize=(10, 5))
for name, group in tqdm(groups):
    plt.bar(group['Year'], group['Value'])

plt.title('Total Greenhouse Gas Emission (Linear)')
plt.xlabel('Year')
plt.ylabel('Tonnes')
plt.show()

# for name, group in tqdm(groups):
#     plt.bar(group['Year'], group['Value'])

# plt.title('Total Greenhouse Gas Emission (Log)')
# plt.yscale('log')
# plt.xlabel('Year')
# plt.ylabel('Tonnes')
# plt.show()
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 63/63 [00:22<00:00,  2.75it/s]
# CPU times: user 41.4 s, sys: 984 ms, total: 42.4 s
# Wall time: 41.6 s
